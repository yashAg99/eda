# %% [markdown]
# #### EDA Assignment ############

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
df = pd.read_csv("netflix_titles2.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Task 1: Data Overview

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Task 2: Univariate Analysis

# %%
num_cols = ['age', 'watch_hours', 'monthly_fee', 'churned']

for col in num_cols:
    plt.figure(figsize=(6, 4))
    #sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
cat_cols = ['subscription_type', 'gender', 'region', 'device', 'payment_method', 'favorite_genre']

for col in cat_cols:
    plt.figure(figsize=(7, 4))
    #sns.countplot(x=col, data=df)
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Task 3: Bivariate Analysis

# %%
cols_to_compare = ['subscription_type', 'region', 'device']
for col in cols_to_compare:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    #sns.barplot(x=col, y='watch_hours', data=df, ax=axes[0])
    axes[0].set_title(f'Average Watch Hours by {col}')
    axes[0].tick_params(axis='x', rotation=45)
    
    #sns.barplot(x=col, y='monthly_fee', data=df, ax=axes[1])
    axes[1].set_title(f'Average Monthly Fee by {col}')
    axes[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(8, 4))
#sns.barplot(x='favorite_genre', y='avg_watch_time_per_day', data=df)
plt.title('Average Daily Watch Time by Genre')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
churn_cols = ['gender', 'region', 'subscription_type', 'payment_method']

for col in churn_cols:
    plt.figure(figsize=(6, 4))
    #churn_rate = df.groupby(col)['churned'].mean().reset_index()
    #sns.barplot(x=col, y='churned', data=churn_rate)
    plt.title(f'Churn Rate by {col}')
    plt.xticks(rotation=45)
    plt.ylabel("Churn Rate")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Task 4: Correlation Analysis

# %%
plt.figure(figsize=(10, 6))
#sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap - Numerical Variables")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task 5: Insights & Recommendations ✍️

# %% [markdown]
# #
# 1. Here are 5–7 sample insights you might include based on the visualizations:
#
# 2. Churn Prediction: Users with lower watch_hours and lower avg_watch_time_per_day show higher churn rates.
#
# 3. Subscription Type Impact: Premium users have higher monthly fees, but their churn rate is lower compared to Basic users.
#
# 4. Region Differences: North America shows the highest average watch_hours, but also slightly higher churn than other regions.
#
# 5. Device Usage: Users watching on TVs have higher watch_hours and lower churn compared to mobile users.
#
# 6. Favorite Genre Behavior: Users who prefer Thriller and Drama tend to watch more daily than those who prefer Documentaries.
#
# 7. Payment Method Effect: Churn is higher among users using debit cards compared to UPI or credit cards.
#
# 8. Login Patterns: last_login_days is negatively correlated with watch_hours, and strongly correlated with churn, making it a potential churn predictor.#
